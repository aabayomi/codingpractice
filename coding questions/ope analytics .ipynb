# %%
import pandas as pd
import numpy as np
from datetime import datetime

data = pd.DataFrame.from_csv("/Users/abayomi/Desktop/Cramer Ck at US Hwy 54 nr Dalhart, TX.csv")
# new =data.drop(['site_no', 'tz_cd','112840_00060_cd','112843_00065_cd'], axis=1)
# new = new.fillna(0)
print data.head()
# new = new['datetime'] = pd.to_datetime(new['datetime'])
# print data.head()
# new = data.groupby(data.index.hour).mean()
print new.head()
# type(new[1])
# Out:
# Empty DataFrame
# Columns: []
# Index: [5s	15s	20d	6s	14n	10s	14n	10s, USGS	7227420	10/1/2007 0:00	CDT			0	A, USGS	7227420	10/1/2007 0:15	CDT			0	A, USGS	7227420	10/1/2007 0:30	CDT			0	A, USGS	7227420	10/1/2007 0:45	CDT			0	A]

# %%
import pandas as pd
import numpy as numpy

dic = {}
df =  pd.read_csv('/Users/abayomi/Desktop/Cramer Ck at US Hwy 54 nr Dalhart, TX.csv',sep='\t')



print df

# df.columns = ['Date','Guage']

# print df.head()

# print(df)

# data=df.groupby(['Datetime']).groups.keys()
#df=df.groupby('Date')['Guage'].mean()
# df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# df.set_index('Date', inplace=True)

#converted = df.asfreq('45min', method='pad')
#df = df.resample('D', how='mean')
# ohlc_dict = {'Guage': 'mean'}
# df= df.resample('D', closed='right').agg(ohlc_dict).fillna("N/A")


#print (df.head(30))
# df.to_csv('08093100_Brazos.csv')

# print (df)

#def makeDateRange(start, end):
#    date_series = pd.date_range(start=start, end= end)
#    date_series = date_series.normalize()
#print(date_series)
    #return date_series

#def makeDateRangeList(date_series):

#    dates_s = []
#    for i in date_series:
#        i = str(i).replace(r'-','').repalce(r'00.00.00','')
#        i = str(i).repalce(r'00.00.00','')
        #i = i.split("-")
#        iyear = i[0]
#        iday = i[2]
#        if(len(str(iday)) > 1 and int(str(iday)[:1]) ==0):
#            iday= str(iday)[1:]
#        imonth = i[1]
#        if (len(str(imonth)) > 1 and int(str(imonth)[:1]) == 0):
#            imonth = str(imonth)[1:]
#        i = "/".join([imonth, iday, iyear])
#        dates_s.append(i)
        #return date_s



#for dates in df['Date']:
#    dates = str(dates).split()[0]
#    dic[dates] = dic.get(dates, 0) + 1

#print(dates)

#data=df.groupby('Datetime')['Guage'].mean()
#print (data)
#for dates in dic:
#    print (dates)


    #data=df.groupby(['Datetime']).groups.keys()
    #data=df.groupby('Datetime')['Guage'].mean()
#print(data)
#while (dates):
    #print ('the average is: ')
#    for dates in df:
#        split = split()
#        if dates == splitter[0] and dates!=" ":
#            print (splitter [0]+ "\t"+":"+"\t"+ splitter[1])
#    break
# Out:
#        agency_cd\tsite_no\tdatetime\ttz_cd\t139218_00065\t139218_00065_cd\t139220_00060\t139220_00060_cd
# 0                    5s\t15s\t20d\t6s\t14n\t10s\t14n\t10s
# 1            USGS\t7227420\t10/1/2007 0:00\tCDT\t\t\t0\tA
# 2            USGS\t7227420\t10/1/2007 0:15\tCDT\t\t\t0\tA
# 3            USGS\t7227420\t10/1/2007 0:30\tCDT\t\t\t0\tA
# 4            USGS\t7227420\t10/1/2007 0:45\tCDT\t\t\t0\tA
# 5        USGS\t7227420\t10/1/2007 1:00\tCDT\t2.9\tA\t0\tA
# 6        USGS\t7227420\t10/1/2007 1:15\tCDT\t2.9\tA\t0\tA
# 7        USGS\t7227420\t10/1/2007 1:30\tCDT\t2.9\tA\t0\tA
# 8        USGS\t7227420\t10/1/2007 1:45\tCDT\t2.9\tA\t0\tA
# 9        USGS\t7227420\t10/1/2007 2:00\tCDT\t2.9\tA\t0\tA
# 10       USGS\t7227420\t10/1/2007 2:15\tCDT\t2.9\tA\t0\tA
# 11       USGS\t7227420\t10/1/2007 2:30\tCDT\t2.9\tA\t0\tA
# 12       USGS\t7227420\t10/1/2007 2:45\tCDT\t2.9\tA\t0\tA
# 13       USGS\t7227420\t10/1/2007 3:00\tCDT\t2.9\tA\t0\tA
# ...

# %%
# import os
# myhost = os.uname()[1]
# print myhost

import getpass
username = getpass.getuser()
print username
# Out:
# abayomi
